# %%
from sagemaker import get_execution_role
from sagemaker.sklearn.estimator import SKLearn

role = get_execution_role()#'AmazonSageMaker-ExecutionRole-20200607T125385'

# Create the SKLearn Object by directing it to the aws_sklearn_main.py script
aws_sklearn = SKLearn(entry_point='nb_model.py',
                      train_instance_type='ml.m5.xlarge',
                      role=role)

# Train the model using by passing the path to the S3 bucket with the training data
aws_sklearn.fit({'train': 's3://covid-19-claims/claims.csv'})

# Deploy model
aws_sklearn_predictor = aws_sklearn.deploy(instance_type='ml.t2.medium', 
                                           initial_instance_count=1)

# Print the endpoint to test in next step
print(aws_sklearn_predictor.endpoint)
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 2020-06-15 05:41:23 Starting - Starting the training job...
# 2020-06-15 05:41:25 Starting - Launching requested ML instances......
# 2020-06-15 05:42:31 Starting - Preparing the instances for training...
# 2020-06-15 05:43:08 Downloading - Downloading input data...
# 2020-06-15 05:43:45 Training - Training image download completed. Training in progress.2020-06-15 05:43:46,120 sagemaker-containers INFO     Imported framework sagemaker_sklearn_container.training
# 2020-06-15 05:43:46,122 sagemaker-containers INFO     No GPUs detected (normal if no gpus installed)
# 2020-06-15 05:43:46,132 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2020-06-15 05:43:46,423 sagemaker-containers INFO     Module nb_train_model does not provide a setup.py.
# Generating setup.py
# 2020-06-15 05:43:46,423 sagemaker-containers INFO     Generating setup.cfg
# ...

# %%
# Uncomment and run to terminate the endpoint after you are finished
aws_sklearn_predictor.delete_endpoint()
