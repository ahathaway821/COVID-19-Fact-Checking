# %%
# !pip install beautifulsoup4
# !pip install soupsieve
import pandas as pd
import requests
from bs4 import BeautifulSoup
import pandas as pd
from urllib.request import Request, urlopen
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (4.6.3)
# Requirement already satisfied: soupsieve in /usr/local/lib/python3.6/dist-packages (2.0.1)

# %%
url = 'https://www.who.int/emergencies/diseases/novel-coronavirus-2019/advice-for-public/myth-busters'
req = Request(url , headers={'User-Agent': 'Mozilla/5.0'})

webpage = urlopen(req).read()
soup = BeautifulSoup(webpage, 'html.parser')
myths = soup.find_all('div', attrs={'class':'sf-content-block content-block'})

# %%
d = []

for myth in myths:
  myth_header = myth.find('h2')
  if myth_header:
    header_text = myth_header.text
    myth_content = myth.find('p')
    if myth_content:
      content_text = myth_content.text
    d.append({ 'claim_header': header_text, 'claim_content': content_text})

df = pd.DataFrame(d)
df
# Out:
#                                          claim_header                                      claim_content
# 0        Most people who get COVID-19 recover from it  Most people who get COVID-19 have mild or mode...
# 1   Drinking alcohol does not protect you against ...  The harmful use of alcohol increases your risk...
# 2             Thermal scanners CANNOT detect COVID-19  Thermal scanners are effective in detecting pe...
# 3   There are currently no drugs licensed for the ...  While several drug trials are ongoing, there i...
# 4   Adding pepper to your soup or other meals DOES...  Hot peppers in your food, though very tasty, c...
# 5      COVID-19 IS NOT transmitted through houseflies  To date, there is no evidence or information t...
# 6   Spraying and introducing bleach or another dis...  Do not under any circumstance spray or introdu...
# 7   Drinking methanol, ethanol or bleach DOES NOT ...  Methanol, ethanol, and bleach are poisons. Dri...
# 8           5G mobile networks DO NOT spread COVID-19  Viruses cannot travel on radio waves/mobile ne...
# 9   Exposing yourself to the sun or to temperature...  You can catch COVID-19, no matter how sunny or...
# 10  You can recover from the coronavirus disease (...  Most of the people who catch COVID-19 can reco...
# 11  Being able to hold your breath for 10 seconds ...  The most common symptoms of COVID-19 are dry c...
# 12  Drinking alcohol does not protect you against ...  Frequent or excessive alcohol consumption can ...
# 13  COVID-19 virus can be transmitted in areas wit...  The best way to protect yourself against COVID...
# 14  Cold weather and snow CANNOT kill the new coro...  There is no reason to believe that cold weathe...
# 15  Taking a hot bath does not prevent the new cor...  Taking a hot bath will not prevent you from ca...
# 16  The new coronavirus CANNOT be transmitted thro...  To date there has been no information nor evid...
# 17  Are hand dryers effective in killing the new c...  No. Hand dryers are not effective in killing t...
# 18  Ultra-violet (UV) lamps should not be used to ...  UV radiation can cause skin irritation and dam...
# 19            Thermal scanners CANNOT detect COVID-19  Thermal scanners are effective in detecting pe...
# 20  Do vaccines against pneumonia protect you agai...  No. Vaccines against pneumonia, such as pneumo...
# 21  Can regularly rinsing your nose with saline he...  No. There is no evidence that regularly rinsin...
# 22  Can eating garlic help prevent infection with ...  Garlic is a healthy food that may have some an...
# 23  Does the new coronavirus affect older people, ...  People of all ages can be infected by the new ...
# 24  Are antibiotics effective in preventing and tr...  No, antibiotics do not work against viruses, o...
# 25  Are there any specific medicines to prevent or...  To date, there is no specific medicine recomme...

# %%
df.to_csv('who_myths.csv')
